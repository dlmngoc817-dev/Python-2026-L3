# %%
# ex1
import math
radius = int(input("Enter the circle radius: "))
a = (radius * radius) * 3.14

print(f"Circle area = {a}")
# Out:
# Circle area = 254.34

# %%
# ex2
celsius = float(input("Enter the temperature in Celsiys:"))
fahrenheit = celsius * 9 / 5 + 32
print(f"{celsius:g} (C) = {fahrenheit} (F)")
# Out:
# 98 (C) = 208.4 (F)

# %%
# ex3
a = int(input("Enter a number? "))

if a < 2:
    is_prime = False
else:
    is_prime = True
    for divisor in range(2, a):
        if a % divisor == 0:
            is_prime = False
            break

if is_prime:
    print(f"{a} is a prime number")
else:
    print(f"{a} is a NOT prime number")
# Out:
# 1 is a NOT prime number

# %%
# ex4
a = int(input("Enter a number? "))
total = 0

for divisor in range(1, a):
    if a % divisor == 0:
        total += divisor #total = total + divisor 

if total == a and a > 0:
    print(f"{a} is a perfect number")
else:
    print(f"{a} is a NOT perfect number")

# %%
# ex5:
colorlist = ('Red', 'Blue', 'Green', 'White', 'Yellow', 'Purple', 'Black')

color = input("What is your favorite color? ")

 #find the color fav of user (inlist)
if color in colorlist:
    index = colorlist.index(color)
    print(f"Your colod is at index {index} in my list")
else:
    
    print("Sorry, I could not find your color")
# Out:
# Your color is at index 0 in my list

# %%
#ex6: 
# start = 0, end before 7
print("range 1:", end=" ")
print(*range(7), sep=", ")

# start = 1, end before 13
print("range 2:", end=" ")
print(*range(1, 13, 3), sep=", ")

#start = 5, -1, end before 0
print("range 3:", end=" ")
print(*range(5, 0, -1), sep=", ")

# start = 6, - 2, end before -2
print("range 4:", end=" ")
print(*range(6, -2, -2), sep=", ")
# Out:
# range 1: 0, 1, 2, 3, 4, 5, 6
# range 2: 1, 4, 7, 10
# range 3: 5, 4, 3, 2, 1
# range 4: 6, 4, 2, 0

# %%
#ex7:
def remove_dollar_sign(s):
    return s.replace("$", "")
print(remove_dollar_sign("$100$ dollars"))
# Out:
# 100 dollars

# %%
#ex8:
def extract_even(numbers):
    even_numbers = []  # create an empty list

    for number in numbers:
        if number % 2 == 0:
            even_numbers.append(number)

    return even_numbers

print(extract_even([1, 2, 3, 4, 5, 6, 7, 8]))

# %%
# ex9:
def factorial(number):
    #Return the factorial of a non-negative integer
    if number < 0:
        raise ValueError("The number must be non-negative.")

    result = 1
    for value in range(2, number + 1):
        result *= value

    return result


print(factorial(4))
print(factorial(7))
# Out:
# 24
# 5040

# %%
#ex10: 
def get_divisors(n):
    divisors = []
    for i in range(1, n+1):
        if n % i == 0:
            divisors.append(i)
    return divisors

number = int(input("Enter a number: "))
print("Divisors of", number, "are:", get_divisors(number))
# Out:
# Divisors of 90 are: [1, 2, 3, 5, 6, 9, 10, 15, 18, 30, 45, 90]

# %%
# ex11:
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return (dx ** 2 + dy ** 2) ** 0.5


x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

print("Distance:", distance(x1, y1, x2, y2))
# Out:
# Distance: 2.8284271247461903

# %%
def print_pattern(m, n):
    for i in range(m):  
        for j in range(n):
            
            if i == 0 or i == m - 1 or j == 0 or j == n - 1:
                print("*", end=" ")
            else:
                print(" ", end=" ") 
        print() 

# m = 4, n = 5
print_pattern(4, 5)
# Out:
# * * * * *
# *       *
# *       *
# * * * * *
